# %%
# coding: utf-8

import requests

files={'files': open('./submit/submissing_0512_v2.csv','rb')}

data = {
    "user_id": "chizhi",   #user_id is your username which can be found on the top-right corner on our website when you logged in.
    "team_token": "0a621703e4bb49bb9ee37d7018a4f2ac4bfe4bae0d977a5aaa91180484fbb3da", #your team_token.
    "description": '',  #no more than 40 chars.
    "filename": "submissing_0512_v2", #your filename
}

url = 'https://biendata.com/competition/kdd_2018_submit/'

response = requests.post(url, files=files, data=data)

print(response.text)
# Out:
# {"success": true}

# %%
files['files'].read()
# Out:
# b'test_id,PM2.5,PM10,O3\r\naotizhongx_aq#0,5.164848328,16.10161591,54.11050034\r\naotizhongx_aq#1,31.8272419,54.71623993,57.94946671\r\naotizhongx_aq#10,57.23963165,68.54621887,56.58732605\r\naotizhongx_aq#11,57.08078003,68.89976501,56.05691528\r\naotizhongx_aq#12,57.0255928,69.23469543,55.75474167\r\naotizhongx_aq#13,57.0255394,69.5304184,55.6414032\r\naotizhongx_aq#14,57.05700302,69.78705597,55.67692184\r\naotizhongx_aq#15,57.1094017,70.01026154,55.82517242\r\naotizhongx_aq#16,57.17791748,70.20485687,56.05591583\r\naotizhongx_aq#17,57.25955582,70.37226105,56.34412003\r\naotizhongx_aq#18,57.35157776,70.51034546,56.6677742\r\naotizhongx_aq#19,57.45111465,70.61481476,57.00548172\r\naotizhongx_aq#2,55.68025589,83.2696228,61.91143417\r\naotizhongx_aq#20,57.55530548,70.68165588,57.3350029\r\naotizhongx_aq#21,57.66151047,70.70957947,57.63329697\r\naotizhongx_aq#22,57.76744461,70.70159912,57.87809372\r\naotizhongx_aq#23,57.87120438,70.66529083,58.05031586\r\naotizhongx_aq#24,57.97118759,70
# ...
